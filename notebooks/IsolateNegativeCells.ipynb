# %% [markdown]
# ## Imports

# %%
from PIL import Image
import matplotlib.pyplot as plt
import os

# %%
def create_folder(folder_path):
    '''Creates a folder if does not exists.'''
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

# %%
def crop_image(img, crop_size, left, top):
    '''crops the image in the defined size'''
    right = left +  crop_size
    bottom =  top + crop_size
    cropped = img.crop((left, top, right, bottom))
    return cropped

# %%
def visualize(figsize=(15, 15),**images):
    """Plots images in one row."""
    n = len(images)
    plt.figure(figsize=figsize)
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()

# %%
create_folder('../IsolatedCellsDataset/original/all/0')

# %%
image_01 = Image.open('../NegativeSegmentation/1.png')
image_02 = Image.open('../NegativeSegmentation/2.png')
image_03 = Image.open('../NegativeSegmentation/3.png')
image_04 = Image.open('../NegativeSegmentation/4.png')
image_05 = Image.open('../NegativeSegmentation/5.png')
visualize(
    complete_image_01=image_01,
    complete_image_02=image_02,
    complete_image_03=image_03,
    complete_image_04=image_04,
    complete_image_05=image_05   
)

# %%
cell_01 = crop_image(image_01, crop_size=100, left=590, top=1350)
visualize(cell_01 = cell_01)
cell_01.save('../IsolatedCellsDataset/original/all/0/1.png')

# %%
cell_02 = crop_image(image_01, crop_size=100, left=1340, top=1000)
visualize(cell_02 = cell_02)
cell_02.save('../IsolatedCellsDataset/original/all/0/2.png')

# %%
cell_03 = crop_image(image_01, crop_size=100, left=870, top=1100)
visualize(cell_03 = cell_03)
cell_03.save('../IsolatedCellsDataset/original/all/0/3.png')

# %%
cell_04 = crop_image(image_01, crop_size=100, left=30, top=1320)
visualize(cell_04 = cell_04)
cell_04.save('../IsolatedCellsDataset/original/all/0/4.png')

# %%
cell_05 = crop_image(image_02, crop_size=100, left=680, top=0)
visualize(cell_05 = cell_05)
cell_05.save('../IsolatedCellsDataset/original/all/0/5.png')

# %%
cell_06 = crop_image(image_02, crop_size=100, left=1190, top=530)
visualize(cell_06 = cell_06)
cell_06.save('../IsolatedCellsDataset/original/all/0/6.png')

# %%
cell_07 = crop_image(image_02, crop_size=100, left=14, top=290)
visualize(cell_07 = cell_07)
cell_07.save('../IsolatedCellsDataset/original/all/0/7.png')

# %%
cell_08 = crop_image(image_02, crop_size=100, left=1105, top=695)
visualize(cell_08 = cell_08)
cell_08.save('../IsolatedCellsDataset/original/all/0/8.png')

# %%
cell_09 = crop_image(image_03, crop_size=100, left=748, top=20)
visualize(cell_09 = cell_09)
cell_09.save('../IsolatedCellsDataset/original/all/0/9.png')

# %%
cell_10 = crop_image(image_03, crop_size=100, left=120, top=740)
visualize(cell_10 = cell_10)
cell_10.save('../IsolatedCellsDataset/original/all/0/10.png')

# %%
cell_11 = crop_image(image_03, crop_size=100, left=1030, top=990)
visualize(cell_11 = cell_11)
cell_11.save('../IsolatedCellsDataset/original/all/0/11.png')

# %%
cell_12 = crop_image(image_03, crop_size=100, left=1390, top=1400)
visualize(cell_12 = cell_12)
cell_12.save('../IsolatedCellsDataset/original/all/0/12.png')

# %%
cell_13 = crop_image(image_04, crop_size=100, left=330, top=1450)
visualize(cell_13 = cell_13)
cell_13.save('../IsolatedCellsDataset/original/all/0/13.png')

# %%
cell_14 = crop_image(image_04, crop_size=100, left=60, top=480)
visualize(cell_14 = cell_14)
cell_14.save('../IsolatedCellsDataset/original/all/0/14.png')

# %%
cell_15 = crop_image(image_04, crop_size=100, left=455, top=1040)
visualize(cell_15 = cell_15)
cell_15.save('../IsolatedCellsDataset/original/all/0/15.png')

# %%
cell_16 = crop_image(image_04, crop_size=100, left=1700, top=120)
visualize(cell_16 = cell_16)
cell_16.save('../IsolatedCellsDataset/original/all/0/16.png')

# %%
cell_17 = crop_image(image_05, crop_size=100, left=1820, top=1450)
visualize(cell_17 = cell_17)
cell_17.save('../IsolatedCellsDataset/original/all/0/17.png')

# %%
cell_18 = crop_image(image_05, crop_size=100, left=1420, top=650)
visualize(cell_18 = cell_18)
cell_18.save('../IsolatedCellsDataset/original/all/0/18.png')

# %%
cell_19 = crop_image(image_05, crop_size=100, left=790, top=1370)
visualize(cell_19 = cell_19)
cell_19.save('../IsolatedCellsDataset/original/all/0/19.png')

# %%
cell_20 = crop_image(image_05, crop_size=100, left=1330, top=460)
visualize(cell_20 = cell_20)
cell_20.save('../IsolatedCellsDataset/original/all/0/20.png')
